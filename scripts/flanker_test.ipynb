# %%
# %matplotlib inline
import nilearn.plotting as niplt
import nibabel as nib
import os

# %%
out_dir = '/Users/alejandro/bin/nipype_dev/local/datasets/ds000102/derivatives/flanker_group/'

# %%
niplt.plot_stat_map(nib.load(
        os.path.join(out_dir, 'stats/contrast_0/zstat1.nii.gz')))

# %%
niplt.plot_stat_map(nib.load(
        os.path.join(out_dir, 'stats/contrast_1/zstat1.nii.gz')))

# %%
niplt.plot_stat_map(nib.load(
        os.path.join(out_dir, 'stats/contrast_2/zstat1.nii.gz')))
